# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('credi_card.csv')
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      50000    1          2         1   57     -1      0     -1      0
# 1      50000    1          1         2   37      0      0      0      0
# 2     500000    1          1         2   29      0      0      0      0
# 3     100000    2          2         2   23      0     -1     -1      0
# 4     140000    2          3         1   28      0      0      2      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0      0  ...      20940      19146      19131      2000     36681     10000
# 1      0  ...      19394      19619      20024      2500      1815       657
# 2      0  ...     542653     483003     473944     55000     40000     38000
# 3      0  ...        221       -159        567       380       601         0
# 4      0  ...      12211      11793       3719      3329         0       432
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0      9000       689       679                           0
# 1      1000      1000       800                           0
# 2     20239     13750     13770                           0
# 3       581      1687      1542                           0
# 4      1000      1000      1000                           0
#
# [5 rows x 24 columns]

# %%
X=df.drop('default payment next month',axis=1)
y=df['default payment next month']

# %%
from sklearn.model_selection import train_test_split

Xtrain,Xtest,ytrain,ytest=train_test_split(X,y,test_size=0.30,random_state=17)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier
from sklearn.impute import KNNImputer
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.preprocessing import StandardScaler,RobustScaler,MinMaxScaler
from sklearn.pipeline import make_pipeline
from sklearn.metrics import confusion_matrix,classification_report

# %%
def model_performance(preprocessor,xtrain,xtest,ytrain,ytest):
    models={
        'DecisionTreeClassifier':DecisionTreeClassifier(),
        'GaussianNB':GaussianNB(),
        'GradientBoostingClassifier':GradientBoostingClassifier(),
        'RandomForestClassifier':RandomForestClassifier(),
        'SVC':SVC(),
        'KNeighborsClassifier':KNeighborsClassifier(),
        'RidgeClassifier': RidgeClassifier()
    }
    for name,model in models.items():
        pipeline=make_pipeline(preprocessor,model)
        pipeline.fit(xtrain,ytrain)
        ypred=pipeline.predict(xtest)

        #checking the metrics of model

        matrix=confusion_matrix(ytest,ypred)
        report=classification_report(ytest,ypred)

        print(f'{name}---confusion_matrix---')
        print(f' {matrix}')
        print(f'{name}---classification_report---')
        print(f"{report}\n")

# %%
preprocessor_01=make_pipeline(KNNImputer(n_neighbors=3),StandardScaler())
preprocessor_02=make_pipeline(KNNImputer(n_neighbors=3),RobustScaler())
preprocessor_03=make_pipeline(KNNImputer(n_neighbors=3),MinMaxScaler())

print("=============== StandardScaler================")
model_performance(preprocessor_01,Xtrain,Xtest,ytrain,ytest)
print("=============== RobustScaler================")
model_performance(preprocessor_02,Xtrain,Xtest,ytrain,ytest)
print("=============== MinmaxdScaler================")
model_performance(preprocessor_03,Xtrain,Xtest,ytrain,ytest)
# Out:
# =============== StandardScaler================
# DecisionTreeClassifier---confusion_matrix---
#  [[202  26]
#  [ 46  27]]
# DecisionTreeClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.81      0.89      0.85       228
#            1       0.51      0.37      0.43        73
#
#     accuracy                           0.76       301
#    macro avg       0.66      0.63      0.64       301
# weighted avg       0.74      0.76      0.75       301
#
#
# GaussianNB---confusion_matrix---
#  [[176  52]
#  [ 30  43]]
# GaussianNB---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81       228
#            1       0.45      0.59      0.51        73
#
#     accuracy                           0.73       301
#    macro avg       0.65      0.68      0.66       301
# weighted avg       0.76      0.73      0.74       301
#
#
# GradientBoostingClassifier---confusion_matrix---
#  [[211  17]
#  [ 56  17]]
# GradientBoostingClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.85       228
#            1       0.50      0.23      0.32        73
#
#     accuracy                           0.76       301
#    macro avg       0.65      0.58      0.59       301
# weighted avg       0.72      0.76      0.72       301
#
#
# RandomForestClassifier---confusion_matrix---
#  [[218  10]
#  [ 55  18]]
# RandomForestClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.80      0.96      0.87       228
#            1       0.64      0.25      0.36        73
#
#     accuracy                           0.78       301
#    macro avg       0.72      0.60      0.61       301
# weighted avg       0.76      0.78      0.75       301
#
#
# SVC---confusion_matrix---
#  [[223   5]
#  [ 70   3]]
# SVC---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.76      0.98      0.86       228
#            1       0.38      0.04      0.07        73
#
#     accuracy                           0.75       301
#    macro avg       0.57      0.51      0.47       301
# weighted avg       0.67      0.75      0.67       301
#
#
# KNeighborsClassifier---confusion_matrix---
#  [[204  24]
#  [ 62  11]]
# KNeighborsClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.83       228
#            1       0.31      0.15      0.20        73
#
#     accuracy                           0.71       301
#    macro avg       0.54      0.52      0.51       301
# weighted avg       0.66      0.71      0.68       301
#
#
# RidgeClassifier---confusion_matrix---
#  [[224   4]
#  [ 68   5]]
# RidgeClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.77      0.98      0.86       228
#            1       0.56      0.07      0.12        73
#
#     accuracy                           0.76       301
#    macro avg       0.66      0.53      0.49       301
# weighted avg       0.72      0.76      0.68       301
#
#
# =============== RobustScaler================
# DecisionTreeClassifier---confusion_matrix---
#  [[196  32]
#  [ 42  31]]
# DecisionTreeClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       228
#            1       0.49      0.42      0.46        73
#
#     accuracy                           0.75       301
#    macro avg       0.66      0.64      0.65       301
# weighted avg       0.74      0.75      0.75       301
#
#
# GaussianNB---confusion_matrix---
#  [[176  52]
#  [ 30  43]]
# GaussianNB---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81       228
#            1       0.45      0.59      0.51        73
#
#     accuracy                           0.73       301
#    macro avg       0.65      0.68      0.66       301
# weighted avg       0.76      0.73      0.74       301
#
#
# GradientBoostingClassifier---confusion_matrix---
#  [[211  17]
#  [ 55  18]]
# GradientBoostingClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.85       228
#            1       0.51      0.25      0.33        73
#
#     accuracy                           0.76       301
#    macro avg       0.65      0.59      0.59       301
# weighted avg       0.73      0.76      0.73       301
#
#
# RandomForestClassifier---confusion_matrix---
#  [[215  13]
#  [ 58  15]]
# RandomForestClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.79      0.94      0.86       228
#            1       0.54      0.21      0.30        73
#
#     accuracy                           0.76       301
#    macro avg       0.66      0.57      0.58       301
# weighted avg       0.73      0.76      0.72       301
#
#
# SVC---confusion_matrix---
#  [[227   1]
#  [ 71   2]]
# SVC---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.86       228
#            1       0.67      0.03      0.05        73
#
#     accuracy                           0.76       301
#    macro avg       0.71      0.51      0.46       301
# weighted avg       0.74      0.76      0.67       301
#
#
# KNeighborsClassifier---confusion_matrix---
#  [[207  21]
#  [ 59  14]]
# KNeighborsClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.78      0.91      0.84       228
#            1       0.40      0.19      0.26        73
#
#     accuracy                           0.73       301
#    macro avg       0.59      0.55      0.55       301
# weighted avg       0.69      0.73      0.70       301
#
#
# RidgeClassifier---confusion_matrix---
#  [[224   4]
#  [ 68   5]]
# RidgeClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.77      0.98      0.86       228
#            1       0.56      0.07      0.12        73
#
#     accuracy                           0.76       301
#    macro avg       0.66      0.53      0.49       301
# weighted avg       0.72      0.76      0.68       301
#
#
# =============== MinmaxdScaler================
# DecisionTreeClassifier---confusion_matrix---
#  [[197  31]
#  [ 44  29]]
# DecisionTreeClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       228
#            1       0.48      0.40      0.44        73
#
#     accuracy                           0.75       301
#    macro avg       0.65      0.63      0.64       301
# weighted avg       0.74      0.75      0.74       301
#
#
# GaussianNB---confusion_matrix---
#  [[176  52]
#  [ 30  43]]
# GaussianNB---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81       228
#            1       0.45      0.59      0.51        73
#
#     accuracy                           0.73       301
#    macro avg       0.65      0.68      0.66       301
# weighted avg       0.76      0.73      0.74       301
#
#
# GradientBoostingClassifier---confusion_matrix---
#  [[210  18]
#  [ 55  18]]
# GradientBoostingClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85       228
#            1       0.50      0.25      0.33        73
#
#     accuracy                           0.76       301
#    macro avg       0.65      0.58      0.59       301
# weighted avg       0.72      0.76      0.73       301
#
#
# RandomForestClassifier---confusion_matrix---
#  [[216  12]
#  [ 58  15]]
# RandomForestClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.79      0.95      0.86       228
#            1       0.56      0.21      0.30        73
#
#     accuracy                           0.77       301
#    macro avg       0.67      0.58      0.58       301
# weighted avg       0.73      0.77      0.72       301
#
#
# SVC---confusion_matrix---
#  [[228   0]
#  [ 71   2]]
# SVC---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.76      1.00      0.87       228
#            1       1.00      0.03      0.05        73
#
#     accuracy                           0.76       301
#    macro avg       0.88      0.51      0.46       301
# weighted avg       0.82      0.76      0.67       301
#
#
# KNeighborsClassifier---confusion_matrix---
#  [[208  20]
#  [ 62  11]]
# KNeighborsClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.84       228
#            1       0.35      0.15      0.21        73
#
#     accuracy                           0.73       301
#    macro avg       0.56      0.53      0.52       301
# weighted avg       0.67      0.73      0.68       301
#
#
# RidgeClassifier---confusion_matrix---
#  [[226   2]
#  [ 69   4]]
# RidgeClassifier---classification_report---
#               precision    recall  f1-score   support
#
#            0       0.77      0.99      0.86       228
#            1       0.67      0.05      0.10        73
#
#     accuracy                           0.76       301
#    macro avg       0.72      0.52      0.48       301
# weighted avg       0.74      0.76      0.68       301

# %% [markdown]
# from the above report all models are baising to  0 except Decesiontreeclasifier
# so we are going to use that algorithem for aprediction

# %%
from sklearn.model_selection import GridSearchCV

classifier=DecisionTreeClassifier(random_state=17)

param_gris={
    'criterion':['gini', 'entropy', 'log_loss'],
    'splitter':['best','random'],
    'max_depth':[3,4,5,6,7,8,9]
}

grid=GridSearchCV(classifier,param_gris,cv=5,verbose=1)
grid.fit(Xtrain,ytrain)
# Out:
# Fitting 5 folds for each of 42 candidates, totalling 210 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=17),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [3, 4, 5, 6, 7, 8, 9],
#                          'splitter': ['best', 'random']},
#              verbose=1)

# %%
grid.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': 3, 'splitter': 'best'}

# %%
grid.best_estimator_.score(Xtest,ytest)
# Out:
# 0.7342192691029901
